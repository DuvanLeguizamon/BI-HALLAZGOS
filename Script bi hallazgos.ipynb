# %%
import pandas as pd
import openpyxl
import os

# %% [markdown]
# Selección carpeta "DESCARGAS SIAPO"
# Selección carpeta "CONSOLIDADO DE FLOTA"

# %%
folder_path = r"C:\Users\jose.alonso\OneDrive - Grupo Express\Python\BI HALLAZGOS\DESCARGAS SIAPO"
folder_path2 = r"C:\Users\jose.alonso\OneDrive - Grupo Express\Python\BI HALLAZGOS\CONSOLIDADO DE FLOTA"

# %% [markdown]
# Selección archivo ""LISTADO DE INFRACCIONES""
# Selección archivo ¨FLOTA CEXP SIEF"

# %%
df_listado_infracciones = pd.read_excel('C:/Users/jose.alonso/OneDrive - Grupo Express/Python/BI HALLAZGOS/LISTADO DE INFRACCIONES/Listado infracciones ICO (Zonal-Troncal).xlsx',sheet_name='Infracciones')
df_flota = pd.read_excel('C:/Users/jose.alonso/OneDrive - Grupo Express/Python/BI HALLAZGOS/FLOTA CEXP SIEF (TOTAL)/FLOTA CEXP SIEF.xlsx',sheet_name='FLOTA CEXP')

# %%
#Lista de todos los archivos en la carpeta "DESCARGAS SIAPO"

# %%
file_list= [f for f in os.listdir(folder_path) if f.endswith('.xlsx')]

# %%
#Lista de todos los archivos en la carpeta "CONSOLIDADO DE FLOTA"

# %%
file_list2= [f for f in os.listdir(folder_path2) if f.endswith('.xlsx')]

# %%
#Cargar archivos en un Dataframe "DESCARGAS SIAPO"

# %%
dataframes=[]

# %%
for file in file_list:
    file_path = os.path.join(folder_path,file)
    df=pd.read_excel(file_path, skiprows=1)
    dataframes.append(df)

# %%
combined_df = pd.concat(dataframes,ignore_index=True)

# %%
#Cargar archivos en un Dataframe "CONSOLIDADO DE FLOTA"

# %%
dataframes2=[]

# %%
for file in file_list2:
    file_path2 = os.path.join(folder_path2,file)
    df=pd.read_excel(file_path2)
    dataframes2.append(df)

# %%
combined_df2 = pd.concat(dataframes2,ignore_index=True)

# %%
#Validación de información "DESCARGA HALLAZGOS"

# %%
combined_df.head()
# Out:
#         Id Tipo de Concesión              Concesionario        Zona  \
# 0  1443736             ZONAL  CONSORCIO EXPRESS USAQUEN  USAQUEN ZN
# 1  1442902             ZONAL  CONSORCIO EXPRESS USAQUEN  USAQUEN ZN
# 2  1443098             ZONAL  CONSORCIO EXPRESS USAQUEN  USAQUEN ZN
# 3  1443255             ZONAL  CONSORCIO EXPRESS USAQUEN  USAQUEN ZN
# 4  1443396             ZONAL  CONSORCIO EXPRESS USAQUEN  USAQUEN ZN
#
#         Area Tipo Novedad  Id Novedad SAE  Id Novedad Fecha Novedad  \
# 0  VEHICULOS        I5005             NaN     1443736    2024-11-02
# 1  VEHICULOS      I5013-1             NaN     1442902    2024-11-01
# 2  VEHICULOS      I5013-1             NaN     1443098    2024-11-01
# 3  VEHICULOS      I5013-1             NaN     1443255    2024-11-01
# 4  VEHICULOS      I5013-1             NaN     1443396    2024-11-01
#
#   Hora Novedad  ... Número de Documento  \
# 0     09:21:00  ...                 NaN
# 1     03:55:00  ...                 NaN
# 2     05:05:00  ...                 NaN
# 3     12:19:00  ...                 NaN
# 4     10:30:00  ...                 NaN
#
#                                  Descripción Novedad  Unnamed: 16 Unnamed: 17  \
# 0  En el proceso de habilitación del vehículo se ...          NaN         NaN
# 1  El vehículo se dispone a salir de patio a oper...          NaN         NaN
# 2  El vehículo se dispone a salir de patio a oper...          NaN         NaN
# 3  En el proceso de habilitación del vehículo se ...          NaN         NaN
# 4  Realizando la inspección a flota disponible al...          NaN         NaN
#
#    Ultima Etapa Estado Ultima Etapa        Tiempo Restante  \
# 0     ETAPA 0.0  HALLAZGO INFORMADO  1 dd 4 hh 29 mm 30 ss
# 1     ETAPA 0.0  HALLAZGO INFORMADO   2 dd 4 hh 29 mm 9 ss
# 2     ETAPA 0.0  HALLAZGO INFORMADO  2 dd 4 hh 29 mm 13 ss
# 3     ETAPA 0.0  HALLAZGO INFORMADO  3 dd 4 hh 29 mm 28 ss
# 4     ETAPA 0.0  HALLAZGO INFORMADO  3 dd 4 hh 29 mm 28 ss
#
#    Fecha Notificación Observaciones Última Etapa  \
# 0          2024-11-02                        NaN
# 1          2024-11-01                        NaN
# 2          2024-11-01                        NaN
# 3          2024-11-02                        NaN
# 4          2024-11-02                        NaN
#
#   Fecha y Hora Registro Última Etapa
# 0                2024-11-02 19:02:23
# 1                2024-11-01 19:03:02
# 2                2024-11-01 19:03:06
# 3                2024-11-02 19:02:21
# 4                2024-11-02 19:02:21
#
# [5 rows x 24 columns]

# %%
#Validación de información "CONSOLIDADO DE FLOTA"

# %%
combined_df2.sample(5)
# Out:
#             Fecha   Placa No Interno    Centro Operación  \
# 119879 2024-02-03  KYR390    Z157160                Bosa
# 790526 2024-09-19  WLV192       N624  20 de Julio - DUAL
# 822691 2024-09-30  WHT475    Z157056          Gaviotas A
# 625422 2024-07-25  WEW633    Z102141                Bosa
# 365356 2024-04-27  WGH709       D542  20 de Julio - DUAL
#
#        Estado Consorcio Express
# 119879             EN OPERACION
# 790526             EN OPERACION
# 822691             EN OPERACION
# 625422             EN OPERACION
# 365356             EN OPERACION

# %%
#Eliminar columnas no necesarias "DESCARGA HALLAZGOS"

# %%
combined_df = combined_df.drop(columns=["Unnamed: 16","Unnamed: 17"])

# %%
combined_df.head()
# Out:
#         Id Tipo de Concesión              Concesionario        Zona  \
# 0  1443736             ZONAL  CONSORCIO EXPRESS USAQUEN  USAQUEN ZN
# 1  1442902             ZONAL  CONSORCIO EXPRESS USAQUEN  USAQUEN ZN
# 2  1443098             ZONAL  CONSORCIO EXPRESS USAQUEN  USAQUEN ZN
# 3  1443255             ZONAL  CONSORCIO EXPRESS USAQUEN  USAQUEN ZN
# 4  1443396             ZONAL  CONSORCIO EXPRESS USAQUEN  USAQUEN ZN
#
#         Area Tipo Novedad  Id Novedad SAE  Id Novedad Fecha Novedad  \
# 0  VEHICULOS        I5005             NaN     1443736    2024-11-02
# 1  VEHICULOS      I5013-1             NaN     1442902    2024-11-01
# 2  VEHICULOS      I5013-1             NaN     1443098    2024-11-01
# 3  VEHICULOS      I5013-1             NaN     1443255    2024-11-01
# 4  VEHICULOS      I5013-1             NaN     1443396    2024-11-01
#
#   Hora Novedad  ... Tarjeta del Conductor Tipo de Documento  \
# 0     09:21:00  ...                   NaN               NaN
# 1     03:55:00  ...                   NaN               NaN
# 2     05:05:00  ...                   NaN               NaN
# 3     12:19:00  ...                   NaN               NaN
# 4     10:30:00  ...                   NaN               NaN
#
#    Número de Documento                                Descripción Novedad  \
# 0                  NaN  En el proceso de habilitación del vehículo se ...
# 1                  NaN  El vehículo se dispone a salir de patio a oper...
# 2                  NaN  El vehículo se dispone a salir de patio a oper...
# 3                  NaN  En el proceso de habilitación del vehículo se ...
# 4                  NaN  Realizando la inspección a flota disponible al...
#
#    Ultima Etapa Estado Ultima Etapa        Tiempo Restante Fecha Notificación  \
# 0     ETAPA 0.0  HALLAZGO INFORMADO  1 dd 4 hh 29 mm 30 ss         2024-11-02
# 1     ETAPA 0.0  HALLAZGO INFORMADO   2 dd 4 hh 29 mm 9 ss         2024-11-01
# 2     ETAPA 0.0  HALLAZGO INFORMADO  2 dd 4 hh 29 mm 13 ss         2024-11-01
# 3     ETAPA 0.0  HALLAZGO INFORMADO  3 dd 4 hh 29 mm 28 ss         2024-11-02
# 4     ETAPA 0.0  HALLAZGO INFORMADO  3 dd 4 hh 29 mm 28 ss         2024-11-02
#
#   Observaciones Última Etapa Fecha y Hora Registro Última Etapa
# 0                        NaN                2024-11-02 19:02:23
# 1                        NaN                2024-11-01 19:03:02
# 2                        NaN                2024-11-01 19:03:06
# 3                        NaN                2024-11-02 19:02:21
# 4                        NaN                2024-11-02 19:02:21
#
# [5 rows x 22 columns]

# %%
#Convertir columnas a formato fecha

# %%
combined_df['Fecha Novedad']=pd.to_datetime(combined_df['Fecha Novedad'])
combined_df['Fecha Notificación']=pd.to_datetime(combined_df['Fecha Notificación'])

# %%
#Ordenar fecha de archivo

# %%
combined_df=combined_df.sort_values(by="Fecha Novedad")

# %%
#Crear columna calculada CONCAT "DESCARGA HALLAZGOS"

# %%
combined_df['Placa_fecha'] = combined_df['Placa']+combined_df['Fecha Novedad'].dt.strftime('%Y%m%d')

# %%
combined_df.head()
# Out:
#            Id Tipo de Concesión              Concesionario        Zona  \
# 5318  1406475             ZONAL  CONSORCIO EXPRESS USAQUEN  USAQUEN ZN
# 5176  1406117             ZONAL  CONSORCIO EXPRESS USAQUEN  USAQUEN ZN
# 5175  1406063             ZONAL  CONSORCIO EXPRESS USAQUEN  USAQUEN ZN
# 5174  1406033             ZONAL  CONSORCIO EXPRESS USAQUEN  USAQUEN ZN
# 5228  1406153             ZONAL  CONSORCIO EXPRESS USAQUEN  USAQUEN ZN
#
#            Area Tipo Novedad  Id Novedad SAE  Id Novedad Fecha Novedad  \
# 5318  VEHICULOS        I5007             NaN     1406475    2024-09-02
# 5176  VEHICULOS        I5016             NaN     1406117    2024-09-02
# 5175  VEHICULOS      I5003-4             NaN     1406063    2024-09-02
# 5174  VEHICULOS      I5003-4             NaN     1406033    2024-09-02
# 5228  VEHICULOS        I5017             NaN     1406153    2024-09-02
#
#      Hora Novedad  ... Tipo de Documento Número de Documento  \
# 5318     12:42:00  ...               NaN                 NaN
# 5176     05:07:00  ...               NaN                 NaN
# 5175     04:54:00  ...               NaN                 NaN
# 5174     05:50:00  ...               NaN                 NaN
# 5228     03:52:00  ...               NaN                 NaN
#
#                                     Descripción Novedad Ultima Etapa  \
# 5318  En el proceso de habilitación del vehículo se ...    ETAPA 0.2
# 5176  En el proceso de inmovilización del vehículo s...    ETAPA 0.2
# 5175  El vehículo se dispone a salir de patio a oper...    ETAPA 0.2
# 5174  El vehículo se dispone a salir de patio a oper...    ETAPA 0.2
# 5228  En el proceso de inmovilización del vehículo s...    ETAPA 0.2
#
#                                     Estado Ultima Etapa Tiempo Restante  \
# 5318  HALLAZGO CONTESTADO CONTUNDENTE POR CONCESIONA...        Detenido
# 5176  HALLAZGO CONTESTADO CONTUNDENTE POR CONCESIONA...        Detenido
# 5175  HALLAZGO CONTESTADO CONTUNDENTE POR CONCESIONA...        Detenido
# 5174  HALLAZGO CONTESTADO CONTUNDENTE POR CONCESIONA...        Detenido
# 5228  HALLAZGO CONTESTADO CONTUNDENTE POR CONCESIONA...        Detenido
#
#      Fecha Notificación                         Observaciones Última Etapa  \
# 5318         2024-09-03  Contestado contundentemente en tiempo de corre...
# 5176         2024-09-02                                                NaN
# 5175         2024-09-02  Contestado contundentemente en tiempo de corre...
# 5174         2024-09-02                                                NaN
# 5228         2024-09-02                                                NaN
#
#      Fecha y Hora Registro Última Etapa     Placa_fecha
# 5318                2024-09-09 16:36:08  WGH29720240902
# 5176                2024-09-04 12:26:03  WDE89220240902
# 5175                2024-09-04 17:07:30  WGG36520240902
# 5174                2024-09-05 10:02:56  WGG67920240902
# 5228                2024-09-04 12:30:42  WGG53320240902
#
# [5 rows x 23 columns]

# %%
#Crear columna calculada CONCAT "CONSOLIDADO DE FLOTA"

# %%
combined_df2['Placa_fecha'] = combined_df2['Placa']+combined_df2['Fecha'].dt.strftime('%Y%m%d')

# %%
combined_df2.head()
# Out:
#        Fecha   Placa No Interno       Centro Operación  \
# 0 2023-12-25  TGW270       D100  20 de Julio - TRONCAL
# 1 2023-12-25  TGW803       N100  20 de Julio - TRONCAL
# 2 2023-12-25  TGW802       D101  20 de Julio - TRONCAL
# 3 2023-12-25  TGW955       D102  20 de Julio - TRONCAL
# 4 2023-12-25  TGW956       D103  20 de Julio - TRONCAL
#
#   Estado Consorcio Express     Placa_fecha
# 0             EN OPERACION  TGW27020231225
# 1             EN OPERACION  TGW80320231225
# 2             EN OPERACION  TGW80220231225
# 3             EN OPERACION  TGW95520231225
# 4             EN OPERACION  TGW95620231225

# %%
#Función de reemplazo en valores de "Linea" de la "Flota"

# %%
def reemplazar_linea(Linea):
    if Linea.startswith('B330R'):
        return 'B330R'
    elif Linea.startswith('NPR'):
        return 'NPR'
    else:
        return Linea

# %%
#Reemplazar columna "Linea" en el Dataframe

# %%
df_flota['Linea'] = df_flota['Linea'].apply(reemplazar_linea)

# %%
# Calcular Marca - Linea en "FLOTA"

# %%
df_flota['Marca - linea'] = df_flota['Marca']+" "+df_flota['Linea']

# %%
df_flota.sample(5)
# Out:
#        Placa No. Interno Componente Tipo Servicio      Concesión Clase  \
# 1265  WEU930    Z15-4195      ZONAL        URBANO  SAN CRISTOBAL   Bus
# 2559  JTP550    Z10-7291      ZONAL        URBANO        USAQUEN   Bus
# 2077  WGH588    Z10-4546      ZONAL        URBANO        USAQUEN   Bus
# 1989  WGH272    Z15-4220      ZONAL        URBANO  SAN CRISTOBAL   Bus
# 2276  TGX768    Z10-7171      ZONAL        URBANO        USAQUEN   Bus
#
#      Tipo Bus  Modelo          Marca       Linea  ... Valor Fecha Compra  \
# 1265      BUS    2014  MERCEDES BENZ  ATEGO 1016  ...   0.0   07.11.2013
# 2559   PADRON    2021          VOLVO       B330R  ...   NaN   01.01.1990
# 2077      BUS    2015      CHEVROLET         NQR  ...   NaN   30.04.2014
# 1989      BUS    2015      CHEVROLET         NQR  ...   NaN   30.04.2014
# 2276   PADRON    2014          VOLVO       B290R  ...   NaN   28.02.2014
#
#      NIT Propietario        Propietario RUNT            No. Contrato  \
# 1265       900365740   CONSORCIO EXPRESS SAS   CONSORCIO EXPRESS SAS
# 2559       900365740   CONSORCIO EXPRESS SAS   CONSORCIO EXPRESS SAS
# 2077       901712459  TRANSICIÓN EXPRESS SAS  TRANSICIÓN EXPRESS SAS
# 1989       901712459  TRANSICIÓN EXPRESS SAS  TRANSICIÓN EXPRESS SAS
# 2276       901712459  TRANSICIÓN EXPRESS SAS  TRANSICIÓN EXPRESS SAS
#
#      Observación      SOAT Fecha Ultima Modificacion ITS  \
# 1265         NaN  86817958                26.08.2024  NO
# 2559         NaN  86817928                11.03.2024  SI
# 2077         NaN  87948073                18.06.2024  NO
# 1989         NaN  87947618                15.04.2024  NO
# 2276         NaN  86733162                11.03.2024  NO
#
#                  Marca - linea
# 1265  MERCEDES BENZ ATEGO 1016
# 2559               VOLVO B330R
# 2077             CHEVROLET NQR
# 1989             CHEVROLET NQR
# 2276               VOLVO B290R
#
# [5 rows x 55 columns]

# %%
#Dejar unicamente información necesaria en el Dataframe "CONSOLIDADO DE FLOTA"

# %%
combined_df2_1 = combined_df2[['Placa_fecha','Centro Operación']]

# %%
#Dejar unicamente información necesaria en el Dataframe "LISTADO DE INFRACCIONES"

# %%
df_listado_infracciones2 = df_listado_infracciones[['CÓDIGO INFRACCIÓN','DESCRIPCIÓN','PUNTAJE','DÍAS DE CORRECCIÓN']]

# %%
#Ajustar nombre de columna para hacer MERGE

# %%
df_listado_infracciones2 = df_listado_infracciones2.rename(columns={'CÓDIGO INFRACCIÓN': 'Tipo Novedad'})

# %%
df_listado_infracciones2.head()
# Out:
#   Tipo Novedad                                        DESCRIPCIÓN  PUNTAJE  \
# 0        I5001  Instalación de aditamentos que no son del vehí...       10
# 1      I5003-1    Carencia de elementos, sueltos o en mal estado.       30
# 2      I5003-2                       Rayones o abolladuras leves.       10
# 3      I5003-3                    Testigos encendidos color rojo.       30
# 4      I5003-4                 Testigos encendidos color amarillo       10
#
#    DÍAS DE CORRECCIÓN
# 0                   2
# 1                  30
# 2                  10
# 3                   5
# 4                   2

# %%
#Dejar unicamente información necesaria en el Dataframe "FLOTA"

# %%
df_flota2=df_flota[['Placa','Marca - linea']]

# %%
df_flota2.sample(5)
# Out:
#        Placa      Marca - linea
# 2041  WEW528       VOLVO B215RH
# 2698  KYS061  SCANIA F280 IB4X2
# 1094  WDE206    BLUE BIRD SIGMA
# 555   VDF004      CHEVROLET NPR
# 783   SMZ395      CHEVROLET NPR

# %%
#Agregar columna calculada "Centro de Operación"

# %%
combined_df = pd.merge(combined_df,combined_df2_1, on='Placa_fecha',how='left')

# %%
combined_df.sample(7)
# Out:
#            Id Tipo de Concesión                    Concesionario  \
# 2419  1423213             ZONAL  CONSORCIO EXPRESS SAN CRISTOBAL
# 590   1409490             ZONAL        CONSORCIO EXPRESS USAQUEN
# 2386  1422965             ZONAL        CONSORCIO EXPRESS USAQUEN
# 4768  1437045             ZONAL        CONSORCIO EXPRESS USAQUEN
# 1641  1417411             ZONAL        CONSORCIO EXPRESS USAQUEN
# 2089  1420252             ZONAL        CONSORCIO EXPRESS USAQUEN
# 5659  1443165             ZONAL        CONSORCIO EXPRESS USAQUEN
#
#                   Zona       Area Tipo Novedad  Id Novedad SAE  Id Novedad  \
# 2419  SAN CRISTOBAL ZN  VEHICULOS      I5003-2             NaN     1423213
# 590         USAQUEN ZN  VEHICULOS      I5003-4             NaN     1409490
# 2386        USAQUEN ZN  VEHICULOS      I5003-3             NaN     1422965
# 4768        USAQUEN ZN  VEHICULOS      I5003-1             NaN     1437045
# 1641        USAQUEN ZN  VEHICULOS      I5003-4             NaN     1417411
# 2089        USAQUEN ZN  VEHICULOS        I5014             NaN     1420252
# 5659        USAQUEN ZN  VEHICULOS      I5003-4             NaN     1443165
#
#      Fecha Novedad Hora Novedad  ... Número de Documento  \
# 2419    2024-09-28     05:21:00  ...                 NaN
# 590     2024-09-07     05:22:00  ...                 NaN
# 2386    2024-09-27     10:33:00  ...                 NaN
# 4768    2024-10-23     05:29:00  ...                 NaN
# 1641    2024-09-19     10:10:00  ...                 NaN
# 2089    2024-09-24     04:21:00  ...                 NaN
# 5659    2024-11-01     10:24:00  ...                 NaN
#
#                                     Descripción Novedad  Ultima Etapa  \
# 2419  Realizando la inspección a flota disponible al...     ETAPA 0.2
# 590   El vehículo se dispone a salir de patio a oper...     ETAPA 0.2
# 2386  Realizando la inspección eléctrica al vehículo...     ETAPA 0.2
# 4768  En el proceso de inmovilización del vehículo s...     ETAPA 0.0
# 1641  El vehículo se dispone a salir de patio a oper...     ETAPA 0.2
# 2089  En el proceso de inmovilización del vehículo s...     ETAPA 0.2
# 5659  El vehículo se dispone a salir de patio a oper...     ETAPA 0.1
#
#                                     Estado Ultima Etapa  \
# 2419  HALLAZGO CONTESTADO CONTUNDENTE POR CONCESIONA...
# 590   HALLAZGO CONTESTADO CONTUNDENTE POR CONCESIONA...
# 2386  HALLAZGO CONTESTADO CONTUNDENTE POR CONCESIONA...
# 4768                                 HALLAZGO INFORMADO
# 1641  HALLAZGO CONTESTADO CONTUNDENTE POR CONCESIONA...
# 2089  HALLAZGO CONTESTADO CONTUNDENTE POR CONCESIONA...
# 5659  HALLAZGO CON TIEMPO DE CORRECCION CONTESTADO P...
#
#              Tiempo Restante Fecha Notificación  \
# 2419                Detenido         2024-09-28
# 590                 Detenido         2024-09-07
# 2386                Detenido         2024-09-28
# 4768  18 dd 4 hh 28 mm 40 ss         2024-10-23
# 1641                Detenido         2024-09-19
# 2089                Detenido         2024-09-24
# 5659                Detenido         2024-11-02
#
#                              Observaciones Última Etapa  \
# 2419  Contestado contundentemente en tiempo de corre...
# 590                                                 NaN
# 2386                                                NaN
# 4768                                                NaN
# 1641                                                NaN
# 2089                      Adjuntar documento soporte OT
# 5659        SE CONTESTA HALLAZGO Y SE ADJUNTA EVIDENCIA
#
#      Fecha y Hora Registro Última Etapa     Placa_fecha Centro Operación
# 2419                2024-10-09 18:12:05  KYS19820240928             Bosa
# 590                 2024-09-12 09:35:11  WHS68620240907         Conejera
# 2386                2024-10-03 08:25:52  WGG63120240927          Usaquen
# 4768                2024-10-23 19:03:28  LSX35020241023          Toberin
# 1641                2024-09-23 05:03:18  WGG32620240919             Suba
# 2089                2024-09-26 07:39:00  WGG61520240924         Engativa
# 5659                2024-11-03 13:47:53  WGG61620241101           Cruces
#
# [7 rows x 24 columns]

# %%
#Agregar columnas calculadas "Marca - linea"

# %%
combined_df = pd.merge(combined_df,df_flota2, on='Placa',how='left')

# %%
combined_df.sample(5)
# Out:
#            Id Tipo de Concesión                    Concesionario  \
# 4401  1434876             ZONAL        CONSORCIO EXPRESS USAQUEN
# 285   1407675             ZONAL  CONSORCIO EXPRESS SAN CRISTOBAL
# 5239  1439857             ZONAL        CONSORCIO EXPRESS USAQUEN
# 3135  1427372             ZONAL        CONSORCIO EXPRESS USAQUEN
# 4643  1436295             ZONAL        CONSORCIO EXPRESS USAQUEN
#
#                   Zona       Area Tipo Novedad  Id Novedad SAE  Id Novedad  \
# 4401        USAQUEN ZN  VEHICULOS      I5003-2             NaN     1434876
# 285   SAN CRISTOBAL ZN  VEHICULOS      I5003-2             NaN     1407675
# 5239        USAQUEN ZN  VEHICULOS      I5012-1             NaN     1439857
# 3135        USAQUEN ZN  VEHICULOS      I5003-2             NaN     1427372
# 4643        USAQUEN ZN  VEHICULOS      I5003-1             NaN     1436295
#
#      Fecha Novedad Hora Novedad  ...  \
# 4401    2024-10-18     14:34:00  ...
# 285     2024-09-04     05:54:00  ...
# 5239    2024-10-28     04:41:00  ...
# 3135    2024-10-05     05:07:00  ...
# 4643    2024-10-22     05:44:00  ...
#
#                                     Descripción Novedad Ultima Etapa  \
# 4401  Realizando la inspección eléctrica al vehículo...    ETAPA 0.2
# 285   El vehículo se dispone a salir de patio a oper...    ETAPA 0.2
# 5239  El vehículo se dispone a salir de patio a oper...    ETAPA 0.2
# 3135  El vehículo se dispone a salir de patio a oper...    ETAPA 0.2
# 4643  En el proceso de inmovilización del vehículo s...    ETAPA 0.1
#
#                                     Estado Ultima Etapa Tiempo Restante  \
# 4401  HALLAZGO CONTESTADO CONTUNDENTE POR CONCESIONA...        Detenido
# 285   HALLAZGO CONTESTADO CONTUNDENTE POR CONCESIONA...        Detenido
# 5239  HALLAZGO CONTESTADO CONTUNDENTE POR CONCESIONA...        Detenido
# 3135  HALLAZGO CONTESTADO CONTUNDENTE POR CONCESIONA...        Detenido
# 4643  HALLAZGO CON TIEMPO DE CORRECCION CONTESTADO P...        Detenido
#
#       Fecha Notificación                         Observaciones Última Etapa  \
# 4401          2024-10-19  CONTESTADO CONTUNDENTEMENTE EN TIEMPO DE CORRE...
# 285           2024-09-04                                                NaN
# 5239          2024-10-28  Contestado contundentemente en tiempo de corre...
# 3135          2024-10-05                                                NaN
# 4643          2024-10-23  Buen día, se contesta hallazgo ID 1436295 móvi...
#
#      Fecha y Hora Registro Última Etapa     Placa_fecha Centro Operación  \
# 4401                2024-10-29 10:46:50  WGG65120241018    San Francisco
# 285                 2024-09-13 03:40:48  WGG33820240904       Gaviotas B
# 5239                2024-10-31 18:43:28  WEW66320241028         Engativa
# 3135                2024-10-16 08:07:01  WEW03120241005       191 Padron
# 4643                2024-10-26 04:31:11  JTP54320241022         Conejera
#
#         Marca - linea
# 4401    CHEVROLET NQR
# 285     CHEVROLET NQR
# 5239    CHEVROLET NQR
# 3135  BLUE BIRD SIGMA
# 4643      VOLVO B330R
#
# [5 rows x 25 columns]

# %%
#Agregar columnas calculadas ""LISTADO DE INFRACCIONES""

# %%
combined_df = pd.merge(combined_df,df_listado_infracciones2, on='Tipo Novedad',how='left')

# %%
combined_df.head()
# Out:
#         Id Tipo de Concesión              Concesionario        Zona  \
# 0  1406475             ZONAL  CONSORCIO EXPRESS USAQUEN  USAQUEN ZN
# 1  1406117             ZONAL  CONSORCIO EXPRESS USAQUEN  USAQUEN ZN
# 2  1406063             ZONAL  CONSORCIO EXPRESS USAQUEN  USAQUEN ZN
# 3  1406033             ZONAL  CONSORCIO EXPRESS USAQUEN  USAQUEN ZN
# 4  1406153             ZONAL  CONSORCIO EXPRESS USAQUEN  USAQUEN ZN
#
#         Area Tipo Novedad  Id Novedad SAE  Id Novedad Fecha Novedad  \
# 0  VEHICULOS        I5007             NaN     1406475    2024-09-02
# 1  VEHICULOS        I5016             NaN     1406117    2024-09-02
# 2  VEHICULOS      I5003-4             NaN     1406063    2024-09-02
# 3  VEHICULOS      I5003-4             NaN     1406033    2024-09-02
# 4  VEHICULOS        I5017             NaN     1406153    2024-09-02
#
#   Hora Novedad  ... Tiempo Restante Fecha Notificación  \
# 0     12:42:00  ...        Detenido         2024-09-03
# 1     05:07:00  ...        Detenido         2024-09-02
# 2     04:54:00  ...        Detenido         2024-09-02
# 3     05:50:00  ...        Detenido         2024-09-02
# 4     03:52:00  ...        Detenido         2024-09-02
#
#                           Observaciones Última Etapa  \
# 0  Contestado contundentemente en tiempo de corre...
# 1                                                NaN
# 2  Contestado contundentemente en tiempo de corre...
# 3                                                NaN
# 4                                                NaN
#
#   Fecha y Hora Registro Última Etapa     Placa_fecha Centro Operación  \
# 0                2024-09-09 16:36:08  WGH29720240902    San Francisco
# 1                2024-09-04 12:26:03  WDE89220240902       191 Padron
# 2                2024-09-04 17:07:30  WGG36520240902         Engativa
# 3                2024-09-05 10:02:56  WGG67920240902             Suba
# 4                2024-09-04 12:30:42  WGG53320240902          Usaquen
#
#      Marca - linea                                 DESCRIPCIÓN PUNTAJE  \
# 0    CHEVROLET NQR  Daño en pintura, logos, señalética, placas      10
# 1  BLUE BIRD SIGMA                Falla o falta de extintores.      30
# 2    CHEVROLET NQR          Testigos encendidos color amarillo      10
# 3    CHEVROLET NQR          Testigos encendidos color amarillo      10
# 4    CHEVROLET NQR    Mal funcionamiento de puertas de acceso.      30
#
#   DÍAS DE CORRECCIÓN
# 0                  5
# 1                  1
# 2                  2
# 3                  2
# 4                  1
#
# [5 rows x 28 columns]

# %%
combined_df = combined_df.drop(columns=["Placa_fecha"])

# %%
combined_df.head()
# Out:
#         Id Tipo de Concesión              Concesionario        Zona  \
# 0  1406475             ZONAL  CONSORCIO EXPRESS USAQUEN  USAQUEN ZN
# 1  1406117             ZONAL  CONSORCIO EXPRESS USAQUEN  USAQUEN ZN
# 2  1406063             ZONAL  CONSORCIO EXPRESS USAQUEN  USAQUEN ZN
# 3  1406033             ZONAL  CONSORCIO EXPRESS USAQUEN  USAQUEN ZN
# 4  1406153             ZONAL  CONSORCIO EXPRESS USAQUEN  USAQUEN ZN
#
#         Area Tipo Novedad  Id Novedad SAE  Id Novedad Fecha Novedad  \
# 0  VEHICULOS        I5007             NaN     1406475    2024-09-02
# 1  VEHICULOS        I5016             NaN     1406117    2024-09-02
# 2  VEHICULOS      I5003-4             NaN     1406063    2024-09-02
# 3  VEHICULOS      I5003-4             NaN     1406033    2024-09-02
# 4  VEHICULOS        I5017             NaN     1406153    2024-09-02
#
#   Hora Novedad  ...                                Estado Ultima Etapa  \
# 0     12:42:00  ...  HALLAZGO CONTESTADO CONTUNDENTE POR CONCESIONA...
# 1     05:07:00  ...  HALLAZGO CONTESTADO CONTUNDENTE POR CONCESIONA...
# 2     04:54:00  ...  HALLAZGO CONTESTADO CONTUNDENTE POR CONCESIONA...
# 3     05:50:00  ...  HALLAZGO CONTESTADO CONTUNDENTE POR CONCESIONA...
# 4     03:52:00  ...  HALLAZGO CONTESTADO CONTUNDENTE POR CONCESIONA...
#
#   Tiempo Restante  Fecha Notificación  \
# 0        Detenido          2024-09-03
# 1        Detenido          2024-09-02
# 2        Detenido          2024-09-02
# 3        Detenido          2024-09-02
# 4        Detenido          2024-09-02
#
#                           Observaciones Última Etapa  \
# 0  Contestado contundentemente en tiempo de corre...
# 1                                                NaN
# 2  Contestado contundentemente en tiempo de corre...
# 3                                                NaN
# 4                                                NaN
#
#    Fecha y Hora Registro Última Etapa Centro Operación    Marca - linea  \
# 0                 2024-09-09 16:36:08    San Francisco    CHEVROLET NQR
# 1                 2024-09-04 12:26:03       191 Padron  BLUE BIRD SIGMA
# 2                 2024-09-04 17:07:30         Engativa    CHEVROLET NQR
# 3                 2024-09-05 10:02:56             Suba    CHEVROLET NQR
# 4                 2024-09-04 12:30:42          Usaquen    CHEVROLET NQR
#
#                                   DESCRIPCIÓN PUNTAJE DÍAS DE CORRECCIÓN
# 0  Daño en pintura, logos, señalética, placas      10                  5
# 1                Falla o falta de extintores.      30                  1
# 2          Testigos encendidos color amarillo      10                  2
# 3          Testigos encendidos color amarillo      10                  2
# 4    Mal funcionamiento de puertas de acceso.      30                  1
#
# [5 rows x 27 columns]

# %%
#Calcular estado del hallazgo sengún información de "Ultima_Etapa","Estado_Ultima_Etapa" y "Tiempo_Restante"

# %%
def calcular_estado(Ultima_Etapa, Estado_Ultima_Etapa,Tiempo_Restante):
    if Ultima_Etapa == 'ETAPA 0.0':
        return 'PENDIENTE POR CONTESTAR'
    elif Ultima_Etapa == 'ETAPA 0.1':
        return 'CONTESTADO'
    elif (Ultima_Etapa == 'ETAPA 0.2' and Estado_Ultima_Etapa == 'HALLAZGO CONTESTADO CONTUNDENTE POR CONCESIONARIO EN TIEMPO DE CORRECCION') or (Ultima_Etapa == 'ETAPA 0.3' and Estado_Ultima_Etapa == 'HALLAZGO CONTESTADO CONTUNDENTE POR CONCESIONARIO EN TIEMPO DE CORRECCION'):
        return 'CONTESTADO CONTUNDENTE'
    elif (Ultima_Etapa == 'ETAPA 0.2' and Estado_Ultima_Etapa == 'HALLAZGO CONTESTADO NO CONTUNDENTE POR CONCESIONARIO EN TIEMPO DE CORRECCION') or (Ultima_Etapa == 'ETAPA 0.3' and Estado_Ultima_Etapa == 'HALLAZGO CONTESTADO NO CONTUNDENTE POR CONCESIONARIO EN TIEMPO DE CORRECCION')or (Ultima_Etapa == 'ETAPA 1.0' and Tiempo_Restante == 'Detenido'):
        return 'NO CONTUNDENTE'
    elif (Ultima_Etapa == 'ETAPA 0.4') or (Ultima_Etapa == 'ETAPA 1.0' and Tiempo_Restante == 'Vencido'):
        return 'VENCIDO'
    else:
        return 'ERROR IDENTIFICACIÓN ESTADO HALLAZGO-VALIDAR BASE SUMINISTRADA'

# %%
#Incluir columna estado en el Dataframe

# %%
combined_df['Estado'] = combined_df.apply(lambda row: calcular_estado(row['Ultima Etapa'], row['Estado Ultima Etapa'], row['Tiempo Restante']), axis=1)

# %%
combined_df.head()
# Out:
#         Id Tipo de Concesión              Concesionario        Zona  \
# 0  1406475             ZONAL  CONSORCIO EXPRESS USAQUEN  USAQUEN ZN
# 1  1406117             ZONAL  CONSORCIO EXPRESS USAQUEN  USAQUEN ZN
# 2  1406063             ZONAL  CONSORCIO EXPRESS USAQUEN  USAQUEN ZN
# 3  1406033             ZONAL  CONSORCIO EXPRESS USAQUEN  USAQUEN ZN
# 4  1406153             ZONAL  CONSORCIO EXPRESS USAQUEN  USAQUEN ZN
#
#         Area Tipo Novedad  Id Novedad SAE  Id Novedad Fecha Novedad  \
# 0  VEHICULOS        I5007             NaN     1406475    2024-09-02
# 1  VEHICULOS        I5016             NaN     1406117    2024-09-02
# 2  VEHICULOS      I5003-4             NaN     1406063    2024-09-02
# 3  VEHICULOS      I5003-4             NaN     1406033    2024-09-02
# 4  VEHICULOS        I5017             NaN     1406153    2024-09-02
#
#   Hora Novedad  ... Tiempo Restante Fecha Notificación  \
# 0     12:42:00  ...        Detenido         2024-09-03
# 1     05:07:00  ...        Detenido         2024-09-02
# 2     04:54:00  ...        Detenido         2024-09-02
# 3     05:50:00  ...        Detenido         2024-09-02
# 4     03:52:00  ...        Detenido         2024-09-02
#
#                           Observaciones Última Etapa  \
# 0  Contestado contundentemente en tiempo de corre...
# 1                                                NaN
# 2  Contestado contundentemente en tiempo de corre...
# 3                                                NaN
# 4                                                NaN
#
#   Fecha y Hora Registro Última Etapa  Centro Operación    Marca - linea  \
# 0                2024-09-09 16:36:08     San Francisco    CHEVROLET NQR
# 1                2024-09-04 12:26:03        191 Padron  BLUE BIRD SIGMA
# 2                2024-09-04 17:07:30          Engativa    CHEVROLET NQR
# 3                2024-09-05 10:02:56              Suba    CHEVROLET NQR
# 4                2024-09-04 12:30:42           Usaquen    CHEVROLET NQR
#
#                                   DESCRIPCIÓN PUNTAJE DÍAS DE CORRECCIÓN  \
# 0  Daño en pintura, logos, señalética, placas      10                  5
# 1                Falla o falta de extintores.      30                  1
# 2          Testigos encendidos color amarillo      10                  2
# 3          Testigos encendidos color amarillo      10                  2
# 4    Mal funcionamiento de puertas de acceso.      30                  1
#
#                    Estado
# 0  CONTESTADO CONTUNDENTE
# 1  CONTESTADO CONTUNDENTE
# 2  CONTESTADO CONTUNDENTE
# 3  CONTESTADO CONTUNDENTE
# 4  CONTESTADO CONTUNDENTE
#
# [5 rows x 28 columns]

# %%
#Validación de información en Blanco

# %%
nan_por_columna2 = combined_df.isna().sum()
print(nan_por_columna2)
# Out:
# Id                                       0
# Tipo de Concesión                        0
# Concesionario                            0
# Zona                                     0
# Area                                     0
# Tipo Novedad                             0
# Id Novedad SAE                        5615
# Id Novedad                               0
# Fecha Novedad                            0
# Hora Novedad                             0
# Código del Bus                           0
# Placa                                    0
# Tarjeta del Conductor                 5725
# Tipo de Documento                     5725
# Número de Documento                   5725
# Descripción Novedad                      0
# Ultima Etapa                             0
# Estado Ultima Etapa                      0
# Tiempo Restante                          0
# Fecha Notificación                       0
# Observaciones Última Etapa            2372
# Fecha y Hora Registro Última Etapa       0
# Centro Operación                         0
# Marca - linea                            0
# DESCRIPCIÓN                              0
# PUNTAJE                                  0
# DÍAS DE CORRECCIÓN                       0
# Estado                                   0
# dtype: int64

# %%
#Filtrar información "No contundente" y "Vencida"

# %%
información_revisión = ['NO CONTUNDENTE', 'VENCIDO']
combined_df_filtrado = combined_df[combined_df['Estado'].isin(información_revisión)]

# %%
combined_df_filtrado.head()
# Out:
#           Id Tipo de Concesión                    Concesionario  \
# 111  1405984             ZONAL        CONSORCIO EXPRESS USAQUEN
# 218  1406681             ZONAL        CONSORCIO EXPRESS USAQUEN
# 291  1407924             ZONAL  CONSORCIO EXPRESS SAN CRISTOBAL
# 387  1408359             ZONAL        CONSORCIO EXPRESS USAQUEN
# 493  1408876             ZONAL        CONSORCIO EXPRESS USAQUEN
#
#                  Zona       Area Tipo Novedad  Id Novedad SAE  Id Novedad  \
# 111        USAQUEN ZN  VEHICULOS      I5003-4       7482563.0     1405984
# 218        USAQUEN ZN  VEHICULOS      I5003-1       7486735.0     1406681
# 291  SAN CRISTOBAL ZN  VEHICULOS        I5016       7482973.0     1407924
# 387        USAQUEN ZN  VEHICULOS      I5003-2       7484183.0     1408359
# 493        USAQUEN ZN  VEHICULOS      I5003-1       7487296.0     1408876
#
#     Fecha Novedad Hora Novedad  ... Tiempo Restante Fecha Notificación  \
# 111    2024-09-02     04:49:00  ...        Detenido         2024-09-02
# 218    2024-09-03     03:35:00  ...        Detenido         2024-09-03
# 291    2024-09-04     12:33:00  ...         Vencido         2024-09-05
# 387    2024-09-05     09:05:35  ...        Detenido         2024-09-05
# 493    2024-09-06     06:01:00  ...        Detenido         2024-09-06
#
#      Observaciones Última Etapa Fecha y Hora Registro Última Etapa  \
# 111                         NaN                2024-09-05 23:50:17
# 218                         NaN                2024-10-04 23:50:10
# 291                         NaN                2024-09-09 23:50:07
# 387                         NaN                2024-09-17 23:50:20
# 493                         NaN                2024-10-09 23:50:14
#
#      Centro Operación  Marca - linea  \
# 111              Suba  CHEVROLET NQR
# 218              Suba  CHEVROLET NPR
# 291            Cruces  CHEVROLET NQR
# 387          Engativa  CHEVROLET NQR
# 493           Toberin  CHEVROLET NQR
#
#                                          DESCRIPCIÓN PUNTAJE  \
# 111               Testigos encendidos color amarillo      10
# 218  Carencia de elementos, sueltos o en mal estado.      30
# 291                     Falla o falta de extintores.      30
# 387                     Rayones o abolladuras leves.      10
# 493  Carencia de elementos, sueltos o en mal estado.      30
#
#     DÍAS DE CORRECCIÓN          Estado
# 111                  2  NO CONTUNDENTE
# 218                 30  NO CONTUNDENTE
# 291                  1         VENCIDO
# 387                 10  NO CONTUNDENTE
# 493                 30  NO CONTUNDENTE
#
# [5 rows x 28 columns]

# %%
print('NOTA: No es posible tener valores NaN en las columnas Código del Bus, Placa, Centro de operación, Descripción, puntaje, días de corrección y estado')
# Out:
# NOTA: No es posible tener valores NaN en las columnas Código del Bus, Placa, Centro de operación, Descripción, puntaje, días de corrección y estado

# %%
#Carpeta para guardar base hallazgos y base para revisión

# %%
save_path= r"C:\Users\jose.alonso\OneDrive - Grupo Express\Python\BI HALLAZGOS\BASE FINAL\archivo_combinado.xlsx"
save_path2= r"C:\Users\jose.alonso\OneDrive - Grupo Express\Python\BI HALLAZGOS\BASE FINAL\archivo_revisión.xlsx"

# %%
combined_df.to_excel(save_path,index=False)
combined_df_filtrado.to_excel(save_path2,index=False)

# %%
print("Archivos exportados en: C:/Users/jose.alonso/OneDrive - Grupo Express/Python/BI HALLAZGOS/BASE FINAL/")
# Out:
# Archivos exportados en: C:/Users/jose.alonso/OneDrive - Grupo Express/Python/BI HALLAZGOS/BASE FINAL/
